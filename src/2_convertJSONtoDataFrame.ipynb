# %%
import json
import pandas as pd

# Load your uploaded file
with open("../data/nusmods_2025_2026_moduleInfo.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Convert to DataFrame
df = pd.DataFrame(data)

df = df[["moduleCode", "title", "description"]]
df.columns = ["course", "title", "description"]
print(df.columns)
df.head()
# Out:
# Index(['course', 'title', 'description'], dtype='object')
#     course                                title  \
# 0  ABM5001            Leadership in Biomedicine
# 1  ABM5002  Advanced Biostatistics for Research
# 2  ABM5003   Biomedical Innovation & Enterprise
# 3  ABM5004                     Capstone Project
# 4  ABM5101                   Applied Immunology
#
#                                          description
# 0  Leadership is fundamental to the success of in...
# 1  This course is served as a concept-based intro...
# 2  This course will furnish students with a thoro...
# 3  This course encompasses research projects rele...
# 4  Advanced immunological applications play impor...

# %%
print(df.shape)
# Out:
# (16531, 3)

# %%
import re
import pandas as pd

# --- Step 1: Extract base module code ---
def simplify_module_code(code: str) -> str:
    """
    Simplify module code by removing trailing letters.
    Example: CS1010A -> CS1010
    """
    if not isinstance(code, str):
        return None
    return re.sub(r"[A-Za-z]+$", "", code)

df["baseCode"] = df["course"].apply(simplify_module_code)

# --- Step 2: Keep only rows whose moduleCode ends with a digit ---
df_filtered = df[df["course"].str[-1].str.isdigit()]

# --- Step 3: Drop duplicates by baseCode, keeping the first one ---
df_filtered = df_filtered.drop_duplicates(subset="baseCode", keep="first").reset_index(drop=True)

# --- Step 4: (Optional) Drop helper column ---
df_filtered = df_filtered.drop(columns=["baseCode"])

df_filtered[df_filtered["course"].isin(["CS1010", "CS2040", "CS2100", "ACC1701"])]
# Out:
#        course                           title  \
# 23    ACC1701  Accounting for Decision Makers
# 1897   CS1010         Programming Methodology
# 1904   CS2040  Data Structures and Algorithms
# 1905   CS2100           Computer Organisation
#
#                                             description
# 23    The course provides an introduction to account...
# 1897  This course introduces the fundamental concept...
# 1904  This course introduces students to the design ...
# 1905  The objective of this course is to familiarise...

# %%
df_filtered.shape
# Out:
# (11627, 3)

# %%
# Save DataFrame to CSV in current working directory
df_filtered.to_csv("../data/nusmods_modules_no_levelprefix.csv", index=False, encoding="utf-8")

# %%
def extract_level(course):
    try:
        num = int(course[-4:])
        return (num // 1000) * 1000
    except ValueError:
        return None

# %%
df_filtered['level'] = df_filtered['course'].apply(extract_level)
df_filtered
# Out:
#         course                                              title  \
# 0      ABM5001                          Leadership in Biomedicine
# 1      ABM5002                Advanced Biostatistics for Research
# 2      ABM5003                 Biomedical Innovation & Enterprise
# 3      ABM5004                                   Capstone Project
# 4      ABM5101                                 Applied Immunology
# ...        ...                                                ...
# 11622   ZB3312  Enhanced Undergraduate Professional Internship...
# 11623   ZB3313  Undergraduate Professional Internship Programm...
# 11624   ZB4171                  Advanced Topics in Bioinformatics
# 11625   ZB4199           Honours Project in Computational Biology
# 11626   ZB4299           Applied Project in Computational Biology
#
#                                              description   level
# 0      Leadership is fundamental to the success of in...  5000.0
# 1      This course is served as a concept-based intro...  5000.0
# 2      This course will furnish students with a thoro...  5000.0
# 3      This course encompasses research projects rele...  5000.0
# 4      Advanced immunological applications play impor...  5000.0
# ...                                                  ...     ...
# 11622  In addition to having an academic science foun...  3000.0
# 11623  In addition to having an academic science foun...  3000.0
# 11624  This is a seminar-style course based on the li...  4000.0
# 11625                                      Not Available  4000.0
# 11626  For Bachelor of Science (Honours) students to ...  4000.0
#
# [11627 rows x 4 columns]

# %%
missing_level = df_filtered[df_filtered['level'].isna()]
missing_level
# Out:
#           course                   title    description  level
# 2211  DMA1401L01  Design Your Own Course  Not Available    NaN
# 2212  DMA1401L02  Design Your Own Course  Not Available    NaN
# 2213  DMA1402L01  Design Your Own Course  Not Available    NaN

# %%
df_dropped = df_filtered.dropna(subset=['level'])
df_dropped = df_dropped.astype({'level': int}).reset_index(drop=True)
df_dropped
# Out:
#         course                                              title  \
# 0      ABM5001                          Leadership in Biomedicine
# 1      ABM5002                Advanced Biostatistics for Research
# 2      ABM5003                 Biomedical Innovation & Enterprise
# 3      ABM5004                                   Capstone Project
# 4      ABM5101                                 Applied Immunology
# ...        ...                                                ...
# 11619   ZB3312  Enhanced Undergraduate Professional Internship...
# 11620   ZB3313  Undergraduate Professional Internship Programm...
# 11621   ZB4171                  Advanced Topics in Bioinformatics
# 11622   ZB4199           Honours Project in Computational Biology
# 11623   ZB4299           Applied Project in Computational Biology
#
#                                              description  level
# 0      Leadership is fundamental to the success of in...   5000
# 1      This course is served as a concept-based intro...   5000
# 2      This course will furnish students with a thoro...   5000
# 3      This course encompasses research projects rele...   5000
# 4      Advanced immunological applications play impor...   5000
# ...                                                  ...    ...
# 11619  In addition to having an academic science foun...   3000
# 11620  In addition to having an academic science foun...   3000
# 11621  This is a seminar-style course based on the li...   4000
# 11622                                      Not Available   4000
# 11623  For Bachelor of Science (Honours) students to ...   4000
#
# [11624 rows x 4 columns]

# %%
df_dropped["level"].unique()
# Out:
# array([5000, 1000, 2000, 3000, 4000, 6000, 8000, 9000])

# %%
df_dropped["prefix"] = df_dropped["course"].str.extract(r"^([A-Za-z]+)")

# %%
df_dropped.head()
# Out:
#     course                                title  \
# 0  ABM5001            Leadership in Biomedicine
# 1  ABM5002  Advanced Biostatistics for Research
# 2  ABM5003   Biomedical Innovation & Enterprise
# 3  ABM5004                     Capstone Project
# 4  ABM5101                   Applied Immunology
#
#                                          description  level prefix
# 0  Leadership is fundamental to the success of in...   5000    ABM
# 1  This course is served as a concept-based intro...   5000    ABM
# 2  This course will furnish students with a thoro...   5000    ABM
# 3  This course encompasses research projects rele...   5000    ABM
# 4  Advanced immunological applications play impor...   5000    ABM

# %%
print(df_dropped["prefix"].unique())
df_dropped["prefix"].nunique()
# Out:
# ['ABM' 'AC' 'ACC' 'ACE' 'ADS' 'AH' 'AI' 'AII' 'AIS' 'ALS' 'AN' 'AR' 'ARD'
#  'ASP' 'AUD' 'AX' 'AY' 'BAA' 'BBB' 'BBP' 'BDC' 'BHD' 'BI' 'BIH' 'BIS' 'BL'
#  'BLD' 'BMA' 'BMC' 'BMD' 'BME' 'BMF' 'BMG' 'BMH' 'BMI' 'BMK' 'BMO' 'BMP'
#  'BMS' 'BMT' 'BMU' 'BMX' 'BN' 'BPM' 'BPS' 'BRP' 'BS' 'BSE' 'BSN' 'BSP'
#  'BSS' 'BST' 'BT' 'BV' 'BWS' 'BX' 'BZD' 'CAH' 'CAS' 'CCS' 'CD' 'CDE' 'CDM'
#  'CE' 'CEG' 'CFA' 'CFG' 'CG' 'CH' 'CHC' 'CIT' 'CK' 'CL' 'CLC' 'CM' 'CMH'
#  'CN' 'COS' 'CP' 'CS' 'CSA' 'CSX' 'CZ' 'DAO' 'DBA' 'DE' 'DEP' 'DI' 'DL'
#  'DMC' 'DMX' 'DOS' 'DSA' 'DSC' 'DSE' 'DSN' 'DSS' 'DTK' 'DTS' 'DY' 'EBA'
#  'EC' 'ECA' 'EE' 'EEK' 'EG' 'EHB' 'EL' 'ELC' 'EM' 'EN' 'ENC' 'ENV' 'ES'
#  'ESE' 'ESP' 'ETP' 'EU' 'EX' 'FAS' 'FDP' 'FE' 'FIN' 'FSC' 'FSP' 'FST' 'FT'
#  'GE' 'GEA' 'GEC' 'GEH' 'GEI' 'GEK' 'GEM' 'GEN' 'GES' 'GESS' 'GET' 'GEX'
#  'GL' 'GMS' 'GPM' 'GS' 'GSA' 'GSN' 'GSS' 'HE' 'HI' 'HLE' 'HM' 'HS' 'HSA'
#  'HSH' 'HSI' 'HSS' 'HY' 'IAN' 'ID' 'IDE' 'IDS' 'IDX' 'IE' 'IFS' 'IGL'
#  'IJS' 'IND' 'INM' 'INT' 'IPM' 'IPS' 'IS' 'ISC' 'ISD' 'ISE' 'ISN' 'ISY'
#  'IT' 'IY' 'JS' 'JSC' 'LA' 'LAB' 'LAC' 'LAD' 'LAF' 'LAG' 'LAH' 'LAJ' 'LAK'
#  'LAL' 'LAM' 'LAR' 'LAS' 'LAT' 'LAV' 'LAX' 'LC' 'LCC' 'LCJ' 'LE' 'LI' 'LL'
#  'LLD' 'LLJ' 'LSE' 'LSM' 'LSX' 'LX' 'MA' 'MB' 'MCI' 'MD' 'MDG' 'ME' 'MEM'
#  'MIC' 'MIH' 'MKT' 'ML' 'MLE' 'MNO' 'MS' 'MSI' 'MST' 'MT' 'MTM' 'MUA'
#  'MUH' 'MUL' 'MUT' 'MUX' 'MW' 'NE' 'NEP' 'NEX' 'NFB' 'NFC' 'NFS' 'NG'
#  'NGN' 'NGT' 'NHS' 'NHT' 'NLM' 'NM' 'NMC' 'NPS' 'NRM' 'NSS' 'NST' 'NSW'
#  'NTW' 'NUR' 'OL' 'OMS' 'OPT' 'OT' 'OY' 'PA' 'PC' 'PE' 'PF' 'PH' 'PHC'
#  'PHM' 'PHS' 'PL' 'PLB' 'PLC' 'PLS' 'PM' 'PP' 'PR' 'PRV' 'PS' 'PX' 'PY'
#  'QF' 'QT' 'RB' 'RD' 'RE' 'RS' 'RVC' 'RVN' 'RVR' 'RVSS' 'RVX' 'RY' 'SA'
#  'SC' 'SCI' 'SDM' 'SE' 'SEA' 'SFI' 'SH' 'SLP' 'SM' 'SN' 'SP' 'SPH' 'SSA'
#  'SSB' 'SSD' 'ST' 'STR' 'SW' 'SWD' 'SWE' 'SWK' 'SWM' 'SYE' 'TBA' 'TC'
#  'TCE' 'TCN' 'TCX' 'TDEE' 'TEE' 'TG' 'THE' 'TIC' 'TIE' 'TMA' 'TME' 'TP'
#  'TPS' 'TR' 'TRA' 'TS' 'TSC' 'TTG' 'UD' 'UIS' 'UPC' 'UTC' 'UTOA' 'UTOB'
#  'UTOC' 'UTOD' 'UTOE' 'UTOM' 'UTON' 'UTOR' 'UTOS' 'UTS' 'VCU' 'VHC' 'VM'
#  'WR' 'XD' 'XFA' 'XFB' 'XFC' 'XFE' 'YCC' 'YCT' 'YHU' 'YID' 'YIR' 'YLC'
#  'YLE' 'YLG' 'YLL' 'YLN' 'YLS' 'YSC' 'YSP' 'YSS' 'ZB']
# 371

# %%
# Save DataFrame to CSV in current working directory
df_dropped.to_csv("../data/nusmods_modules_with_levelprefix.csv", index=False, encoding="utf-8")

# %%
df_dropped[df_dropped['level'] == 2000]
# Out:
#         course                                            title  \
# 24     ACC2706                            Managerial Accounting
# 25     ACC2707               Corporate Accounting & Reporting I
# 26     ACC2708              Corporate Accounting & Reporting II
# 27     ACC2709                   Accounting Information Systems
# 28     ACC2711  Sustainability Metrics and Performance Analysis
# ...        ...                                              ...
# 11370  YSS2252    What is the Global South: Africa in the World
# 11371  YSS2253                                   Divided Cities
# 11372  YSS2254             Statistics for Psychology using SPSS
# 11612   ZB2101                      Introductory Bioinformatics
# 11613   ZB2201         Computational Thinking for Life Sciences
#
#                                              description  level prefix
# 24     This course covers major concepts, tools and t...   2000    ACC
# 25     The course covers financial accounting at an i...   2000    ACC
# 26     The course covers financial accounting at an i...   2000    ACC
# 27     This course aims to help students understand t...   2000    ACC
# 28     In this course we examine how companies are us...   2000    ACC
# ...                                                  ...    ...    ...
# 11370  What is ‘Africa’ and who is African? Is the Af...   2000    YSS
# 11371  This course investigates the social divisions ...   2000    YSS
# 11372  The course introduces the main descriptive and...   2000    YSS
# 11612  Students will be introduced to the concepts, t...   2000     ZB
# 11613  Computational thinking is becoming increasingl...   2000     ZB
#
# [1647 rows x 5 columns]
