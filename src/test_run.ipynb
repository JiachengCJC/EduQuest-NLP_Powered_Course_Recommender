# %%
from EduQuest.client import LocalOllamaClient
from EduQuest.similarity import CosineSimilarityCalculator
from EduQuest.recommend import EmbeddingRecommender

import pandas as pd
import re, json

# %%
ollama_client = LocalOllamaClient(
    generator_model="mistral",
    rec_model="qwen2.5:7b-instruct",
    embedding_model="nomic-embed-text"
)

similarity_calculator = CosineSimilarityCalculator()
Traditional_recModel = EmbeddingRecommender(ollama_client, similarity_calculator)
Similarity_recModel = EmbeddingRecommender(ollama_client, similarity_calculator)

# %%
ori_df = pd.read_pickle('cleaned_nusmods.pkl')    
ori_df.head()
# Out:
#     course                                title  \
# 0  ABM5001            Leadership in Biomedicine
# 1  ABM5002  Advanced Biostatistics for Research
# 2  ABM5003   Biomedical Innovation & Enterprise
# 3  ABM5004                     Capstone Project
# 4  ABM5101                   Applied Immunology
#
#                                          description  level prefix  \
# 0  Leadership is fundamental to the success of in...   5000    ABM
# 1  This course is served as a concept-based intro...   5000    ABM
# 2  This course will furnish students with a thoro...   5000    ABM
# 3  This course encompasses research projects rele...   5000    ABM
# 4  Advanced immunological applications play impor...   5000    ABM
#
#   ori_course_code
# 0         ABM5001
# 1         ABM5002
# 2         ABM5003
# 3         ABM5004
# 4         ABM5101

# %%
ori_df.sample(8)
# Out:
#                                                 course  \
# 6633                                            PP5105
# 7155                                           RVX1004
# 6908                                            PS3215
# 2216                                            EC5101
# 4676  LL4500 (Cross-listed as LL5500, LL6500, LLJ5500)
# 1071                                           CDE2001
# 7174                                            SC2211
# 6904                                            PS2254
#
#                                                   title  \
# 6633             Cost Benefit Analysis in Public Policy
# 7155  Cultural Expressions of Science, Technology an...
# 6908                               Equality and Justice
# 2216                               Microeconomic Theory
# 4676          Recalibrating Multilateral Trading Regime
# 1071              Innovation and Design for Communities
# 7174                                  Medical Sociology
# 6904                   American Government and Politics
#
#                                             description  level prefix  \
# 6633  Cost Benefit Analysis (CBA) is one of the most...   5000     PP
# 7155  Since the 20th century we have witnessed the i...   1000    RVX
# 6908  This course asks questions about the relations...   3000     PS
# 2216  The purpose of this course is to provide stude...   5000     EC
# 4676  This course aims to provide the students with ...   4000     LL
# 1071  This course is designed to facilitate communit...   2000    CDE
# 7174  This course will examine the relationship betw...   2000     SC
# 6904  The American system has been viewed as a model...   2000     PS
#
#      ori_course_code
# 6633          PP5105
# 7155         RVX1004
# 6908          PS3215
# 2216          EC5101
# 4676          LL4500
# 1071         CDE2001
# 7174          SC2211
# 6904          PS2254

# %%
ori_df[ori_df['ori_course_code'] == "CS2040"]
# Out:
#       course                           title  \
# 1709  CS2040  Data Structures and Algorithms
#
#                                             description  level prefix  \
# 1709  This course introduces students to the design ...   2000     CS
#
#      ori_course_code
# 1709          CS2040

# %% [markdown]
# **Run this cell only if have not yet done description embeddings**

# %%
from tqdm import tqdm

# Assume emb_df is already loaded with columns ['course', 'title', 'description', 'level', ...]
new_embeddings = []

async def reembed_all():
    for desc in tqdm(ori_df["description"].tolist()):
        emb = await ollama_client.generate_embedding(desc)
        new_embeddings.append(emb)

await reembed_all()

ori_df['embedding'] = new_embeddings
ori_df = ori_df[["course", "title", "description", "embedding", "level", "prefix", "ori_course_code"]]

ori_df.to_pickle('embeddings_ollama.pkl')
print("✅ Saved new embeddings to embeddings_ollama.pkl")

ori_df.head()
# Out:
# 100%|██████████| 9123/9123 [03:08<00:00, 48.35it/s]
# ✅ Saved new embeddings to embeddings_ollama.pkl
#     course                                title  \
# 0  ABM5001            Leadership in Biomedicine
# 1  ABM5002  Advanced Biostatistics for Research
# 2  ABM5003   Biomedical Innovation & Enterprise
# 3  ABM5004                     Capstone Project
# 4  ABM5101                   Applied Immunology
#
#                                          description  \
# 0  Leadership is fundamental to the success of in...
# 1  This course is served as a concept-based intro...
# 2  This course will furnish students with a thoro...
# 3  This course encompasses research projects rele...
# 4  Advanced immunological applications play impor...
#
#                                            embedding  level prefix  \
# 0  [0.34031474590301514, 0.9926074147224426, -3.2...   5000    ABM
# 1  [1.1152286529541016, 0.348115473985672, -3.109...   5000    ABM
# 2  [-0.37872791290283203, 1.9817829132080078, -3....   5000    ABM
# 3  [0.18893012404441833, 0.6445629000663757, -2.7...   5000    ABM
# 4  [-0.0720033049583435, 0.4849713444709778, -3.2...   5000    ABM
#
#   ori_course_code
# 0         ABM5001
# 1         ABM5002
# 2         ABM5003
# 3         ABM5004
# 4         ABM5101

# %% [markdown]
# **START HERE**

# %%
q1 = "I’m interested in artificial intelligence and how it can be applied in business decision-making. I want to learn both technical and practical aspects of machine learning"
q2 = "I want to understand how humans interact with technology — things like user behavior, data ethics, and human-computer interaction."
q3 = "I’m planning to start my own company in the future and want to take courses that help me understand entrepreneurship, product development, and marketing analytics."
q4 = "I’m fascinated by financial modeling and quantitative trading. I’d like courses that combine programming, statistics, and economics."
q5 = "I want to explore data-driven solutions for climate change and sustainability — especially courses related to environmental policy, analytics, or renewable energy."

# %%
q0 = "I want to learn machine learning and deep learning for real-world applications."

# %%
all_levels = ori_df['level'].unique().tolist()
print(all_levels)
undergrad = [1000, 2000, 3000, 4000]

allprefixes = ori_df['prefix'].unique().tolist()
print(allprefixes)
# Out:
# [5000, 1000, 2000, 3000, 4000, 6000, 9000, 8000]
# ['ABM', 'AC', 'ACC', 'ACE', 'ADS', 'AH', 'AI', 'AII', 'AIS', 'ALS', 'AN', 'AR', 'ARD', 'ASP', 'AUD', 'AX', 'AY', 'BAA', 'BBP', 'BDC', 'BHD', 'BI', 'BIH', 'BIS', 'BL', 'BLD', 'BMA', 'BMC', 'BMD', 'BME', 'BMF', 'BMG', 'BMH', 'BMI', 'BMK', 'BMO', 'BMP', 'BMS', 'BMT', 'BMU', 'BMX', 'BN', 'BPM', 'BPS', 'BRP', 'BS', 'BSE', 'BSN', 'BSP', 'BSS', 'BST', 'BT', 'BWS', 'BX', 'BZD', 'CAH', 'CAS', 'CCS', 'CDE', 'CDM', 'CE', 'CEG', 'CFA', 'CFG', 'CG', 'CH', 'CHC', 'CIT', 'CL', 'CLC', 'CM', 'CMH', 'CN', 'COS', 'CP', 'CS', 'CSA', 'CZ', 'DAO', 'DBA', 'DE', 'DEP', 'DI', 'DL', 'DOS', 'DSA', 'DSC', 'DSE', 'DSN', 'DSS', 'DTK', 'DTS', 'DY', 'EBA', 'EC', 'ECA', 'EE', 'EEK', 'EG', 'EHB', 'EL', 'ELC', 'EM', 'EN', 'ENC', 'ENV', 'ES', 'ESE', 'ESP', 'ETP', 'EU', 'EX', 'FAS', 'FDP', 'FE', 'FIN', 'FSC', 'FSP', 'FST', 'FT', 'GE', 'GEA', 'GEC', 'GEH', 'GEI', 'GEK', 'GEM', 'GEN', 'GES', 'GESS', 'GET', 'GEX', 'GL', 'GMS', 'GS', 'GSA', 'GSN', 'GSS', 'HE', 'HI', 'HLE', 'HM', 'HS', 'HSA', 'HSH', 'HSI', 'HSS', 'HY', 'ID', 'IDE', 'IDS', 'IE', 'IFS', 'IGL', 'IJS', 'IND', 'INM', 'INT', 'IPM', 'IPS', 'IS', 'ISC', 'ISD', 'ISE', 'ISN', 'ISY', 'IT', 'JS', 'JSC', 'LA', 'LAB', 'LAC', 'LAD', 'LAF', 'LAG', 'LAH', 'LAJ', 'LAK', 'LAL', 'LAM', 'LAR', 'LAS', 'LAT', 'LAV', 'LC', 'LCC', 'LCJ', 'LE', 'LI', 'LL', 'LLJ', 'LSE', 'LSM', 'LX', 'MA', 'MB', 'MCI', 'MD', 'MDG', 'ME', 'MEM', 'MIC', 'MIH', 'MKT', 'ML', 'MLE', 'MNO', 'MS', 'MSI', 'MT', 'MTM', 'MUA', 'MUH', 'MUL', 'MUT', 'MW', 'NE', 'NEP', 'NEX', 'NG', 'NGN', 'NGT', 'NHS', 'NHT', 'NLM', 'NM', 'NMC', 'NPS', 'NRM', 'NSS', 'NST', 'NSW', 'NTW', 'NUR', 'OMS', 'OPT', 'OT', 'PA', 'PC', 'PF', 'PH', 'PHC', 'PHM', 'PHS', 'PL', 'PLC', 'PLS', 'PM', 'PP', 'PR', 'PS', 'PX', 'PY', 'QF', 'QT', 'RB', 'RE', 'RVC', 'RVN', 'RVR', 'RVSS', 'RVX', 'SA', 'SC', 'SDM', 'SE', 'SEA', 'SFI', 'SH', 'SLP', 'SM', 'SN', 'SP', 'SPH', 'SSA', 'SSD', 'ST', 'STR', 'SW', 'SWD', 'SWE', 'SWK', 'SWM', 'SYE', 'TBA', 'TC', 'TCE', 'TCN', 'TCX', 'TEE', 'TG', 'THE', 'TIC', 'TIE', 'TMA', 'TME', 'TP', 'TPS', 'TR', 'TRA', 'TS', 'TSC', 'TTG', 'UD', 'UIS', 'UPC', 'UTC', 'UTOA', 'UTOC', 'UTS', 'VCU', 'VHC', 'VM', 'WR', 'XD', 'XFA', 'XFB', 'XFC', 'YCC', 'YCT', 'YHU', 'YID', 'YIR', 'YLC', 'YLE', 'YLG', 'YLL', 'YLN', 'YLS', 'YSC', 'YSP', 'YSS', 'ZB']

# %% [markdown]
# **Similarity way: Build Faiss Index to calculate similarity and Retrieve top-k most similar courses**

# %%
# Step 1: Load courses into the recommendation model
Similarity_recModel.load_courses(ori_df)

# Step 2: Build Faiss Index
await Similarity_recModel.build_faiss_index()
# Out:
# 🔍 Checking for existing embeddings...
# ✅ FAISS index built successfully.

# %%
q1 = "I’d like to work in AI product management and understand both tech and business sides."

# %%
q2="I want to learn machine learning and deep learning for real-world applications."
q3="I’m interested in data mining, big data systems, and analytics engineering."
q4="I plan to start a startup and want entrepreneurship and innovation modules."
q5="I want to learn business analytics and data-driven decision making."
q6="Interested in marketing analytics and consumer insights."
q7="I’m fascinated by quantitative finance and financial modeling."
q8="I want to learn econometrics and causal inference for policy/markets."
q9= "I want to study sustainability, climate policy, and environmental analytics."
q10= "Looking for urban planning, smart cities, and geospatial analytics."
q11="I’m interested in bioinformatics, computational biology, and genomics analytics."
q12="I want healthcare analytics and public health policy modules."
q13= "I want HCI, UX design, and human factors courses."
q14="I’m curious about cognitive psychology and behavioural science."
q15="I want to improve academic writing, communication, and presentation skills."
q16="I’m looking for tech ethics, data privacy, and AI governance courses."
q17="I want to learn robotics, control systems, and perception."
q18="I’m into operations research, optimization, and logistics."
q19="I care about social policy, governance, and public administration."
q20="I want to explore media studies, society, and technology."
q21="I’d like energy systems, renewable technologies, and sustainability engineering."
q22="I’m interested in materials science, nanotech, and semiconductors."
q23="I’m considering a research track and want advanced seminars or capstone-style modules."

# %%
Sim_results, Sim_top10_courses = await Similarity_recModel.recommend_deterministic(q1, top_k=11)

# %%
Sim_top10_courses
# Out:
#                                course  \
# 0                             DBA4813
# 1                             BME5202
# 2                             MSI5002
# 3                             BME5402
# 4                              IS4246
# 5                              IS2108
# 6                              IS4108
# 7                             YSC2257
# 8                              AI5201
# 9                              EE5065
# 10                            BMK5207
# 11                             IS5006
# 12                            BMH5104
# 13                             IS2238
# 14                            AIS5291
# 15                             AI5204
# 16                            UTS2831
# 17  AII5003 (Cross-listed as MSI5003)
# 18                             IS4261
# 19                            BMS5522
# 20                            MSI5102
# 21                             IT5005
# 22                             PR5227
# 23                             HS1501
# 24                             AI5211
# 25                             IS4401
# 26                            MSI5005
# 27                            MSI5001
# 28                             AI5209
# 29                             AI5202
# 30                            BMS5417
# 31                            BMA5431
# 32                             IS4400
# 33                             IS1128
# 34                            BMS5105
# 35                            SPH5424
# 36                             IT1244
# 37                             EE2213
# 38                            CDE5311
# 39                             IS4242
# 40                            BMC5203
# 41                             PP5538
# 42                             AI5208
# 43                            TCX2006
# 44                            BME5104
# 45                             PP5546
# 46                             IE4280
# 47                            BSE3713
# 48                             IS4238
# 49                             CS3263
#
#                                                 title  \
# 0                           AI Strategies in Business
# 1                                 Opportunities in AI
# 2      Management of Technological Innovation with AI
# 3                                           AI in HRM
# 4                     Smart Systems and AI Governance
# 5   Full-stack Software Engineering for AI Solutio...
# 6                     AI Solutioning Capstone Project
# 7                        AI Projects and Case Studies
# 8   Executive Mastery of Artificial Intelligence: ...
# 9                            Tenets of AI in Robotics
# 10                                    AI in Marketing
# 11                  Human-Centred Intelligent Systems
# 12                     Artificial Intelligence for HR
# 13                             Economics of IT and AI
# 14              Industry Internship for AI in Science
# 15  AI-Driven Digital Transformation: Strategies a...
# 16  Global AI Innovations and Singapore Entreprene...
# 17                Innovation & Entrepreneurship in AI
# 18           Designing AI-driven Business Innovations
# 19                                    AI in Marketing
# 20                     Essentials of Machine Learning
# 21                            Artificial Intelligence
# 22                  AI in Pharmaceutical Applications
# 23                Artificial Intelligence and Society
# 24  Healthcare Innovation in the Age of AI: Execut...
# 25            Generative AI and Business Applications
# 26               Selected Topics in AI and Innovation
# 27  Introduction to AI: Concepts, Applications, an...
# 28                    Digital Marketing in the AI Era
# 29  Strategic Applications of Generative AI for Ex...
# 30  Managerial Applications of AI and Machine Lear...
# 31  AI for Talent Management and Organizational De...
# 32                               Human-AI Interaction
# 33                    IT, Management and Organisation
# 34                     Big Data and Business Strategy
# 35                                      AI for Health
# 36     Artificial Intelligence: Technology and Impact
# 37            Introduction to Artificial Intelligence
# 38               Designing UX/UI for Human-Centred AI
# 39                 Intelligent Systems and Techniques
# 40        Corporate Innovation in Big Data and AI Era
# 41             Digital Technologies and Public Policy
# 42  AI in Digital Finance: Strategies and Innovations
# 43            Introduction to AI and Machine Learning
# 44                Emerging Tech and the Value of Data
# 45  AI and Governance: Policy Challenges and Oppor...
# 46   Generative AI and Web3 in Industrial Engineering
# 47                     Industry, Digitization, and AI
# 48                            Strategic Cybersecurity
# 49             Foundations of Artificial Intelligence
#
#                                           description  \
# 0   Artificial Intelligence (AI) is becoming the n...
# 1   This course is designed to explore the transfo...
# 2   Explores the transformative role of artificial...
# 3   Artificial intelligence (AI) and machine learn...
# 4   This course is designed for students who want ...
# 5   Modern business Artificial Intelligence (AI) s...
# 6   Students are required to work (in small groups...
# 7   Learn about AI and machine learning from hands...
# 8   This course equips leaders with the essential ...
# 9   Artificial intelligence (AI) is set to disrupt...
# 10  In recent years, as the quantity of business d...
# 11  This course covers intelligent systems solutio...
# 12  Artificial intelligence (AI) has emerged has a...
# 13  Businesses have been revolutionised with the i...
# 14  Students will spend a semester solving AI-cent...
# 15  AI-Driven Digital Transformation: Strategies a...
# 16  This interdisciplinary course explores Artific...
# 17  Learn to leverage AI for venture creation and ...
# 18  Information technology has fundamentally trans...
# 19  In recent years, AI has become a popular buzzw...
# 20  This course offers an accessible introduction ...
# 21  The study of artificial intelligence, or AI, a...
# 22  This course dives into how Artificial Intellig...
# 23  This course focuses on the role of Artificial ...
# 24  Explore the intersection of artificial intelli...
# 25  Generative Artificial Intelligence (generative...
# 26  This course is designed to explore the cutting...
# 27  This course introduces Artificial Intelligence...
# 28  ‘AI in Digital Marketing: Strategies and Innov...
# 29  This course equips leaders with insights into ...
# 30  This course introduces students to the key con...
# 31  This course introduces students to the key con...
# 32  Artificial Intelligence (AI) technologies have...
# 33  This course introduces students to information...
# 34  Big data and artificial intelligence have allo...
# 35  Artificial Intelligence (AI) is transforming h...
# 36  This course introduces students to artificial ...
# 37  This course provides a practical introduction ...
# 38  This course introduces foundational knowledge ...
# 39  This course provides a broad coverage of intel...
# 40  We are now at the era of AI and . Data and alg...
# 41  Students will gain a comprehensive and deeper ...
# 42  This course examines the transformative role o...
# 43  This course introduces basic concepts in Artif...
# 44  The first half of the course is a non-technica...
# 45  This course critically examines the challenges...
# 46  This course aims to introduce the emerging tec...
# 47  This one-semester course covers core methods i...
# 48  Information Technology (IT) involves using com...
# 49  Artificial intelligence is increasingly integr...
#
#                                             embedding  level prefix  \
# 0   [-0.7067713141441345, 1.785797119140625, -3.08...   4000    DBA
# 1   [-0.7825117707252502, 1.5607876777648926, -2.8...   5000    BME
# 2   [-0.8056091070175171, 1.6745011806488037, -2.7...   5000    MSI
# 3   [-0.7983016967773438, 0.8531933426856995, -3.0...   5000    BME
# 4   [-1.0542210340499878, 1.47096848487854, -3.000...   4000     IS
# 5   [-0.6993556618690491, 1.0005601644515991, -2.6...   2000     IS
# 6   [-0.7475270628929138, 1.2489631175994873, -2.7...   4000     IS
# 7   [0.1369640827178955, 1.289811611175537, -2.427...   2000    YSC
# 8   [-0.693904459476471, 1.6468610763549805, -2.83...   5000     AI
# 9   [-0.2248518168926239, 1.0833220481872559, -2.8...   5000     EE
# 10  [-0.7218471765518188, 0.8799309730529785, -2.7...   5000    BMK
# 11  [-0.725703775882721, 1.070297360420227, -2.921...   5000     IS
# 12  [-1.0028716325759888, 0.749786913394928, -3.22...   5000    BMH
# 13  [-0.7510941028594971, 1.5143264532089233, -3.0...   2000     IS
# 14  [-1.1366971731185913, 1.1787446737289429, -3.1...   5000    AIS
# 15  [-0.6367636919021606, 1.3479952812194824, -2.8...   5000     AI
# 16  [-0.41973990201950073, 1.6087677478790283, -3....   2000    UTS
# 17  [-1.0996229648590088, 2.005056858062744, -3.60...   5000    AII
# 18  [-0.7106176018714905, 1.2535970211029053, -3.4...   4000     IS
# 19  [-0.40409624576568604, 1.3358713388442993, -3....   5000    BMS
# 20  [-0.738131046295166, 0.8172603249549866, -2.77...   5000    MSI
# 21  [-0.19799356162548065, 1.7618004083633423, -2....   5000     IT
# 22  [-0.7567932605743408, 1.2581979036331177, -2.6...   5000     PR
# 23  [-0.6988217234611511, 1.8397343158721924, -2.7...   1000     HS
# 24  [-0.7684979438781738, 2.339250326156616, -2.85...   5000     AI
# 25  [-1.0181784629821777, 1.4531738758087158, -2.6...   4000     IS
# 26  [-0.6956495046615601, 1.6338849067687988, -2.6...   5000    MSI
# 27  [-0.23615752160549164, 1.2614409923553467, -2....   5000    MSI
# 28  [-1.4062341451644897, 1.505001425743103, -3.23...   5000     AI
# 29  [-0.736436128616333, 1.7854863405227661, -2.76...   5000     AI
# 30  [-1.0599530935287476, 0.8661273717880249, -2.9...   5000    BMS
# 31  [-1.1722438335418701, 0.8914442658424377, -2.8...   5000    BMA
# 32  [-0.5914236307144165, 1.817223310470581, -2.49...   4000     IS
# 33  [-1.2047656774520874, 1.1345237493515015, -2.7...   1000     IS
# 34  [-0.6638572812080383, 1.6567727327346802, -3.3...   5000    BMS
# 35  [-0.3760727345943451, 1.7312226295471191, -2.6...   5000    SPH
# 36  [-0.6610356569290161, 1.2650015354156494, -2.5...   1000     IT
# 37  [-0.4398285746574402, 1.1910336017608643, -2.3...   2000     EE
# 38  [-0.5487651228904724, 1.499603509902954, -2.46...   5000    CDE
# 39  [-0.12758682668209076, 1.2713737487792969, -3....   4000     IS
# 40  [-0.7616169452667236, 1.1978529691696167, -3.2...   5000    BMC
# 41  [-0.44686856865882874, 1.3302838802337646, -2....   5000     PP
# 42  [0.26371437311172485, 1.768640398979187, -3.40...   5000     AI
# 43  [-0.11199178546667099, 1.4878100156784058, -2....   2000    TCX
# 44  [-0.14613914489746094, 1.9794559478759766, -2....   5000    BME
# 45  [0.10573962330818176, 1.92026686668396, -2.780...   5000     PP
# 46  [-0.9136878252029419, 0.9624982476234436, -3.1...   4000     IE
# 47  [-0.41981297731399536, 1.6721599102020264, -3....   3000    BSE
# 48  [0.3560678958892822, 1.173922061920166, -3.122...   4000     IS
# 49  [0.11212801188230515, 1.6131870746612549, -2.6...   3000     CS
#
#    ori_course_code  similarity
# 0          DBA4813    0.810678
# 1          BME5202    0.797669
# 2          MSI5002    0.780681
# 3          BME5402    0.766276
# 4           IS4246    0.763267
# 5           IS2108    0.761519
# 6           IS4108    0.760017
# 7          YSC2257    0.757500
# 8           AI5201    0.755185
# 9           EE5065    0.753826
# 10         BMK5207    0.748332
# 11          IS5006    0.747205
# 12         BMH5104    0.745933
# 13          IS2238    0.743178
# 14         AIS5291    0.742395
# 15          AI5204    0.735414
# 16         UTS2831    0.734427
# 17         AII5003    0.733046
# 18          IS4261    0.731227
# 19         BMS5522    0.729125
# 20         MSI5102    0.727763
# 21          IT5005    0.727075
# 22          PR5227    0.726291
# 23          HS1501    0.725949
# 24          AI5211    0.725834
# 25          IS4401    0.723139
# 26         MSI5005    0.721493
# 27         MSI5001    0.721352
# 28          AI5209    0.719929
# 29          AI5202    0.719300
# 30         BMS5417    0.719114
# 31         BMA5431    0.717714
# 32          IS4400    0.717149
# 33          IS1128    0.716564
# 34         BMS5105    0.716381
# 35         SPH5424    0.715138
# 36          IT1244    0.713102
# 37          EE2213    0.712335
# 38         CDE5311    0.705558
# 39          IS4242    0.704943
# 40         BMC5203    0.704386
# 41          PP5538    0.704359
# 42          AI5208    0.701746
# 43         TCX2006    0.701333
# 44         BME5104    0.699797
# 45          PP5546    0.696892
# 46          IE4280    0.696688
# 47         BSE3713    0.696066
# 48          IS4238    0.695188
# 49          CS3263    0.695099

# %%
Sim_results = []
for course_code in Sim_top10_courses["course"]:
    result_code = course_code.split(" ")[0]
    Sim_results.append(result_code)

Sim_df = pd.DataFrame(Sim_results, columns=['course_code'])
Sim_df

# %%
print(Sim_results)

# %% [markdown]
# **LLM way: Use LLM to directly recommend courses based on user query**

# %%
emb_df = pd.read_pickle('embeddings_ollama.pkl')

# %%
Traditional_recModel.load_courses(emb_df)

# %%
text_output, course_df = await Traditional_recModel.recommend(q0, type=1)
print(text_output)

# %%
course_df

# %%
tra_data = text_output.split('\n')
print(tra_data)

# %%
course_name = []
for i in range(0, len(tra_data), 4):
    course_info = tra_data[i]
    course_info= re.sub(r"^[^A-Za-z]*", "", course_info)
    code, title = course_info.split(":", 1)
    course_name.append(code)

print(course_name)

# %%
tra_df = pd.DataFrame(course_name, columns=['course_name'])
tra_df

# %%
all(tra_df["course_name"].isin(ori_df["ori_course_code"]))  # should be True

# %%
tra_df[~tra_df["course_name"].isin(ori_df["ori_course_code"])]

# %%
same_courses = pd.merge(tra_df, Sim_df, left_on='course_name', right_on='course_code', how='inner')
print(same_courses)
print(f"Same courses: {len(same_courses)}")
